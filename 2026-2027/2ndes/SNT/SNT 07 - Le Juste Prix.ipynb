# %% [markdown]
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.5.0/css/all.min.css"/>
# <h2 style="color:#4A5D7A;font-family:sans-serif;font-weight:bold;font-size:2em;margin:25px 0 15px 0;padding-bottom:8px;border-bottom:3px solid #4A5D7A;">Séance 07 - Le Juste Prix </h2>
# <div style="background-color:#EBF0F7;border:2px solid #4A5D7A;border-radius:6px;padding:14px 20px;margin:12px 0;font-family:sans-serif;"><span style="color:#4A5D7A;font-weight:bold;font-size:0.92em;text-transform:uppercase;letter-spacing:0.8px;">Objectifs de la séance</span><ul style="margin-top:10px;color:#333;"><li style="margin:5px 0;">Utiliser la fonction <code>input()</code> pour saisir des données au clavier</li><li style="margin:5px 0;">Convertir une chaîne en entier avec <code>int()</code></li><li style="margin:5px 0;">Écrire et utiliser une boucle <code>while</code></li><li style="margin:5px 0;">Combiner conditions <code>if/elif/else</code> dans un programme complet</li></ul></div>

# %% [markdown]
# <div style="background-color:#FAFAFA;border:1px solid #ddd;border-radius:6px;padding:16px 22px;margin:14px 0;font-family:sans-serif;"><span style="color:#4A5D7A;font-weight:bold;font-size:0.92em;text-transform:uppercase;letter-spacing:0.8px;">Table des matières</span><ul style="margin-top:12px;padding-left:12px;color:#333;list-style:none;"><li style="margin:5px 0;"><a href="#section-1" style="color:#D36740;text-decoration:none;font-weight:bold;">1. Présentation du jeu</a></li><li style="margin:5px 0;"><a href="#section-2" style="color:#D36740;text-decoration:none;font-weight:bold;">2. Découverte : la fonction <code>input()</code></a></li><ul style="margin:3px 0 3px 16px;padding:0;list-style:none;"><li style="margin:3px 0;"><a href="#ex1" style="color:#EA8556;text-decoration:none;">Exercice 1 - Prise en main de <code>input()</code></a></li></ul><li style="margin:5px 0;"><a href="#section-3" style="color:#D36740;text-decoration:none;font-weight:bold;">3. Découverte : les nombres aléatoires</a></li><ul style="margin:3px 0 3px 16px;padding:0;list-style:none;"><li style="margin:3px 0;"><a href="#ex2" style="color:#EA8556;text-decoration:none;">Exercice 2 - Nombres aléatoires</a></li></ul><li style="margin:5px 0;"><a href="#section-4" style="color:#D36740;text-decoration:none;font-weight:bold;">4. Construction du jeu pas à pas</a></li><ul style="margin:3px 0 3px 16px;padding:0;list-style:none;"><li style="margin:3px 0;"><a href="#ex3" style="color:#EA8556;text-decoration:none;">Exercice 3 - Comparer une proposition au prix</a></li></ul><ul style="margin:3px 0 3px 16px;padding:0;list-style:none;"><li style="margin:3px 0;"><a href="#ex4" style="color:#EA8556;text-decoration:none;">Exercice 4 - Une seule tentative</a></li></ul><ul style="margin:3px 0 3px 16px;padding:0;list-style:none;"><li style="margin:3px 0;"><a href="#ex5" style="color:#EA8556;text-decoration:none;">Exercice 5 - Le jeu complet </a></li></ul><ul style="margin:3px 0 3px 16px;padding:0;list-style:none;"><li style="margin:3px 0;"><a href="#ex6" style="color:#EA8556;text-decoration:none;">Exercice 6 - Compter les essais</a></li></ul><li style="margin:5px 0;"><a href="#section-5" style="color:#D36740;text-decoration:none;font-weight:bold;">5. Améliorations</a></li><ul style="margin:3px 0 3px 16px;padding:0;list-style:none;"><li style="margin:3px 0;"><a href="#ex7" style="color:#EA8556;text-decoration:none;">Exercice 7 - Transformer en fonction</a></li></ul><ul style="margin:3px 0 3px 16px;padding:0;list-style:none;"><li style="margin:3px 0;"><a href="#ex8" style="color:#EA8556;text-decoration:none;">Exercice 8 - Nombre de tentatives limité ⏱</a></li></ul></ul></div>

# %% [markdown]
# <a id="section-1"></a>
# <h3 style="color:#D36740;font-family:sans-serif;font-weight:bold;font-size:1.7em;margin:20px 0 12px 0;padding-bottom:5px;border-bottom:2px solid #D36740;">1. Présentation du jeu</h3>
#
# ---

# %% [markdown]
# <div style="background-color:#EEF1F8;border-left:6px solid #8A9CC1;border-radius:0 6px 6px 0;padding:14px 18px;margin:12px 0;font-family:sans-serif;"><span style="color:#8A9CC1;font-weight:bold;font-size:0.92em;text-transform:uppercase;letter-spacing:0.8px;">Définition</span><div style="margin-top:9px;">
#
# Le **Juste Prix** est un jeu télévisé célèbre dans lequel un candidat doit **deviner le prix d'un objet**.
# À chaque proposition, l'animateur lui indique si le prix réel est **plus cher** ou **moins cher**.
#
# Dans cette séance, nous allons programmer ce jeu en Python ! L'ordinateur choisira un prix aléatoire et vous devrez le deviner. Le programme vous guidera à chaque essai.
#
# Ce projet mobilise plusieurs notions vues depuis le début de l'année :
# - les **variables** et l'**affectation**
# - les **fonctions**
# - les **instructions conditionnelles** (`if`, `elif`, `else`)
# - les **boucles** (`while`)</div></div>

# %% [markdown]
# <a id="section-2"></a>
# <h3 style="color:#D36740;font-family:sans-serif;font-weight:bold;font-size:1.7em;margin:20px 0 12px 0;padding-bottom:5px;border-bottom:2px solid #D36740;">2. Découverte : la fonction `input()`</h3>
#
# ---

# %% [markdown]
# <div style="background-color:#EEF1F8;border-left:6px solid #8A9CC1;border-radius:0 6px 6px 0;padding:14px 18px;margin:12px 0;font-family:sans-serif;"><span style="color:#8A9CC1;font-weight:bold;font-size:0.92em;text-transform:uppercase;letter-spacing:0.8px;">Définition</span><div style="margin-top:9px;">
#
# Pour que le joueur puisse entrer sa proposition, on utilise la fonction `input()` qui permet de **demander une saisie au clavier** à l'utilisateur.
#
# ```python
# reponse = input("Votre message : ")
# ```
#
# **Attention** : la fonction `input()` renvoie toujours une **chaîne de caractères** (du texte). Pour obtenir un nombre entier, il faut convertir le résultat avec `int()` :
#
# ```python
# nombre = int(input("Entrez un nombre : "))
# ```
#
# </div></div>

# %% [markdown]
# <a id="ex1"></a>
# <div style="background-color:#EA8556;color:white;border-radius:4px;padding:10px 18px;margin:20px 0 10px 0;font-family:sans-serif;"><strong style="font-size:1.05em;">Exercice 1 - Prise en main de <code>input()</code></strong></div>
#
# 🐍 **Question 1** : Exécutez la cellule ci-dessous. Tapez votre prénom quand l'ordinateur vous le demande, puis validez avec Entrée.

# %%
prenom = input("Comment vous appelez-vous ? ")
print("Bonjour", prenom, "!")
# Out:
# Comment vous appelez-vous ? Mathilde
# Bonjour Mathilde !

# %% [markdown]
# 🐍 **Question 2** : Exécutez la cellule ci-dessous. Tapez un nombre entier quand l'ordinateur vous le demande.

# %%
nombre = int(input("Entrez un nombre entier : "))
double = nombre * 2
print("Le double de", nombre, "est", double)
# Out:
# Entrez un nombre entier : 13
# Le double de 13 est 26

# %% [markdown]
# ✍️ **Question 3** : Pourquoi est-il nécessaire d'utiliser `int()` autour de `input()` si on veut faire des calculs avec la valeur saisie ?

# %% [raw]
# Votre réponse :

# %% [markdown]
# <a id="section-3"></a>
# <h3 style="color:#D36740;font-family:sans-serif;font-weight:bold;font-size:1.7em;margin:20px 0 12px 0;padding-bottom:5px;border-bottom:2px solid #D36740;">3. Découverte : les nombres aléatoires</h3>
#
# ---

# %% [markdown]
# <div style="background-color:#EEF1F8;border-left:6px solid #8A9CC1;border-radius:0 6px 6px 0;padding:14px 18px;margin:12px 0;font-family:sans-serif;"><span style="color:#8A9CC1;font-weight:bold;font-size:0.92em;text-transform:uppercase;letter-spacing:0.8px;">Définition</span><div style="margin-top:9px;">
#
# Pour que l'ordinateur choisisse un prix au hasard, on utilise le module `random` et sa fonction `randint(a, b)` qui renvoie un **entier aléatoire** compris entre `a` et `b` (inclus).
#
# ```python
# import random
# nombre = random.randint(1, 100)
# ```</div></div>

# %% [markdown]
# <a id="ex2"></a>
# <div style="background-color:#EA8556;color:white;border-radius:4px;padding:10px 18px;margin:20px 0 10px 0;font-family:sans-serif;"><strong style="font-size:1.05em;">Exercice 2 - Nombres aléatoires</strong></div>
#
# 🐍 **Question 1** : Recopiez le programme et exécutez plusieurs fois la cellule ci-dessous.

# %%
# À vous !

# %% [markdown]
# ✍️ **Question 2** : La cellule affiche-t-elle toujours le même nombre ? Pourquoi ?

# %% [raw]
# Votre réponse :

# %% [markdown]
# 🐍 **Question 3** : Modifiez la cellule ci-dessous pour qu'elle génère un nombre aléatoire entre 1 et 500.

# %%
import random
# Modifier la ligne ci-dessous
print(random.randint(1, 100))

# %% [markdown]
# <a id="section-4"></a>
# <h3 style="color:#D36740;font-family:sans-serif;font-weight:bold;font-size:1.7em;margin:20px 0 12px 0;padding-bottom:5px;border-bottom:2px solid #D36740;">4. Construction du jeu pas à pas</h3>
#
# ---

# %% [markdown]
# <a id="ex3"></a>
# <div style="background-color:#EA8556;color:white;border-radius:4px;padding:10px 18px;margin:20px 0 10px 0;font-family:sans-serif;"><strong style="font-size:1.05em;">Exercice 3 - Comparer une proposition au prix</strong></div>
#
# Avant de programmer le jeu complet, on commence par écrire une fonction qui compare la proposition du joueur au prix à deviner.
#
# 🐍 **Question 1** : Compléter la fonction `comparer` ci-dessous. Elle prend en paramètres `proposition` (le nombre proposé par le joueur) et `prix` (le prix à deviner). Elle doit renvoyer :
# - `"C'est plus cher !"` si le prix est supérieur à la proposition
# - `"C'est moins cher !"` si le prix est inférieur à la proposition
# - `"Bravo, c'est le Juste Prix !"` si la proposition est correcte

# %%
def comparer(proposition, prix):
    if ...:
        return ...
    elif ...:
        return ...
    else:
        return ...

# %% [markdown]
# 🐍 **Question 2** : Testez votre fonction avec les appels ci-dessous (le prix secret est 42).

# %%
print(comparer(30, 42))   # doit afficher "C'est plus cher !"
print(comparer(50, 42))   # doit afficher "C'est moins cher !"
print(comparer(42, 42))   # doit afficher "Bravo, c'est le Juste Prix !"

# %% [markdown]
# <a id="ex4"></a>
# <div style="background-color:#EA8556;color:white;border-radius:4px;padding:10px 18px;margin:20px 0 10px 0;font-family:sans-serif;"><strong style="font-size:1.05em;">Exercice 4 - Une seule tentative</strong></div>
#
# On va maintenant écrire un premier programme (sans boucle) qui :
# 1. Choisit un prix aléatoire entre 1 et 100
# 2. Demande au joueur de deviner
# 3. Affiche si c'est plus cher, moins cher, ou le juste prix
#
# 🐍 **Question** : Compléter le programme ci-dessous.

# %%
import random

prix = ... # Aide toi de l'exercice 2

proposition = ... # Aide toi de l'exercice 1

# Compléter avec un if/elif/else pour afficher le bon message
if ...:
    print(...)
elif ...:
    print(...)
else:
    print(...)

# %% [markdown]
# <div style="background-color:#FDF6E3;border-left:6px solid #E6B459;border-radius:0 6px 6px 0;padding:14px 18px;margin:12px 0;font-family:sans-serif;"><span style="color:#9a7010;font-weight:bold;font-size:0.92em;text-transform:uppercase;letter-spacing:0.8px;">Remarque</span><div style="margin-top:9px;">
#
# Ce programme ne permet qu'**une seule tentative**. Si le joueur ne trouve pas du premier coup, il ne peut pas réessayer. C'est là que la boucle `while` va être utile !</div></div>

# %% [markdown]
# <a id="ex5"></a>
# <div style="background-color:#EA8556;color:white;border-radius:4px;padding:10px 18px;margin:20px 0 10px 0;font-family:sans-serif;"><strong style="font-size:1.05em;">Exercice 5 - Le jeu complet </strong></div>
#
# On veut maintenant que le joueur puisse proposer **autant de fois qu'il le souhaite** jusqu'à trouver le bon prix.
#
# <div style="background-color:#FDF6E3;border-left:6px solid #E6B459;border-radius:0 6px 6px 0;padding:14px 18px;margin:12px 0;font-family:sans-serif;"><span style="color:#9a7010;font-weight:bold;font-size:0.92em;text-transform:uppercase;letter-spacing:0.8px;">Remarque</span><div style="margin-top:9px;">
#
# **Indication** : on doit répéter la demande de proposition **tant que** le joueur n'a pas trouvé le bon prix.</div></div>
#
# 🐍 **Question 1** : Compléter le programme ci-dessous pour que le jeu se répète tant que le joueur n'a pas trouvé.

# %%
import random

prix = random.randint(1, 100)
proposition = -1  # valeur initiale différente du prix (donc nimporte quel nombre plus petit que 1 ou plus grand que 100)

while ... :
    proposition = ...
    
    if ...:
        print(...)
    elif ...:
        print(...)
    else:
        print(...)

# %% [markdown]
# ✍️ **Question 2** : Quelle est la condition de la boucle `while` ? Quand cette condition devient-elle fausse (et donc quand la boucle s'arrête-t-elle) ?

# %% [raw]
# Votre réponse :

# %% [markdown]
# <a id="ex6"></a>
# <div style="background-color:#EA8556;color:white;border-radius:4px;padding:10px 18px;margin:20px 0 10px 0;font-family:sans-serif;"><strong style="font-size:1.05em;">Exercice 6 - Compter les essais</strong></div>
#
# Pour rendre le jeu plus intéressant, on souhaite compter le **nombre d'essais** du joueur et l'afficher à la fin.
#
# 🐍 **Question 1** : Recopiez le programme de l'exercice 5, puis modifiez-le pour :
# - ajouter une variable `essais` initialisée à 0
# - l'augmenter de 1 à chaque tentative du joueur
# - afficher le nombre d'essais à la fin (quand le joueur a trouvé)

# %%
import random

prix = random.randint(1, 100)
proposition = -1  # valeur initiale différente du prix (donc nimporte quel nombre plus petit que 1 ou plus grand que 100)
essais = ...  # initialiser le compteur

while ... :
    proposition = ...
    essais = ...  # incrémenter le compteur
    if ...:
        print(...)
    elif ...:
        print(...)
    else:
        print(...)

# %% [markdown]
# <a id="section-5"></a>
# <h3 style="color:#D36740;font-family:sans-serif;font-weight:bold;font-size:1.7em;margin:20px 0 12px 0;padding-bottom:5px;border-bottom:2px solid #D36740;">5. Améliorations</h3>
#
# ---

# %% [markdown]
# <a id="ex7"></a>
# <div style="background-color:#EA8556;color:white;border-radius:4px;padding:10px 18px;margin:20px 0 10px 0;font-family:sans-serif;"><strong style="font-size:1.05em;">Exercice 7 - Transformer en fonction</strong></div>
#
# On souhaite transformer notre jeu en une **fonction** pour pouvoir facilement modifier les paramètres.
#
# 🐍 **Question** : Écrire une fonction `juste_prix(prix_max)` qui :
# - choisit un prix aléatoire entre 1 et `prix_max`
# - laisse le joueur deviner avec les indications "plus cher" / "moins cher"
# - **renvoie** le nombre d'essais quand le joueur a trouvé
#
# Ainsi, `juste_prix(100)` lancera une partie avec un prix entre 1 et 100, et `juste_prix(500)` une partie avec un prix entre 1 et 500.

# %%
import random

def juste_prix(prix_max):
    # Compléter ci-dessous
    ...

# %% [markdown]
# 🐍 Testez votre fonction :

# %%
# Lancez une partie !
juste_prix(100)

# %% [markdown]
# <a id="ex8"></a>
# <div style="background-color:#EA8556;color:white;border-radius:4px;padding:10px 18px;margin:20px 0 10px 0;font-family:sans-serif;"><strong style="font-size:1.05em;">Exercice 8 - Nombre de tentatives limité </strong></div>
#
# Dans la vraie émission du Juste Prix, le nombre de tentatives est limité !
#
# 🐍 **Question** : Modifier votre fonction pour qu'elle prenne un deuxième paramètre `max_essais` et que le jeu s'arrête si le joueur dépasse ce nombre de tentatives. Dans ce cas, le programme affiche le prix qu'il fallait trouver.
#
# <div style="background-color:#FDF6E3;border-left:6px solid #E6B459;border-radius:0 6px 6px 0;padding:14px 18px;margin:12px 0;font-family:sans-serif;"><span style="color:#9a7010;font-weight:bold;font-size:0.92em;text-transform:uppercase;letter-spacing:0.8px;">Remarque</span><div style="margin-top:9px;">
#
# **Indication** : la boucle `while` doit maintenant vérifier **deux conditions** : le joueur n'a pas trouvé **et** il lui reste des essais. Rappel : on combine deux conditions avec le mot clé `and`.</div></div>

# %%
# À vous, copiez et collez ce que vous avez déjà fait plus modifiez le !

# %% [markdown]
# 🐍 Testez votre jeu avec différentes difficultés :

# %%
# Facile : prix entre 1 et 50, 10 essais

# %%
# Difficile : prix entre 1 et 1000, 10 essais
